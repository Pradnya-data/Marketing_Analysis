# %% [markdown]
#  Analyze customer data from a digital marketing campaign to: <br>
#
# 1.Understand customer demographics and behavior
#
# 2.Identify high-value customer segments
#
# 3.Recommend marketing strategies to improve campaign performance

# %% [markdown]
# Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load and Explore the dataset

# %%
df=pd.read_csv("digital_marketing_campaign_dataset.csv")
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           8000 non-null   int64
#  1   Age                  8000 non-null   int64
#  2   Gender               8000 non-null   object
#  3   Income               8000 non-null   int64
#  4   CampaignChannel      8000 non-null   object
#  5   CampaignType         8000 non-null   object
#  6   AdSpend              8000 non-null   float64
#  7   ClickThroughRate     8000 non-null   float64
#  8   ConversionRate       8000 non-null   float64
#  9   WebsiteVisits        8000 non-null   int64
#  10  PagesPerVisit        8000 non-null   float64
#  11  TimeOnSite           8000 non-null   float64
#  12  SocialShares         8000 non-null   int64
#  13  EmailOpens           8000 non-null   int64
#  14  EmailClicks          8000 non-null   int64
# ...

# %%
df.shape
# Out:
# (8000, 20)

# %% [markdown]
# # Insights
# Dataset consists of 8000 records with 20 columns

# %%
df['CampaignChannel'].value_counts()
# Out:
# CampaignChannel
# Referral        1719
# PPC             1655
# Email           1557
# SEO             1550
# Social Media    1519
# Name: count, dtype: int64

# %% [markdown]
# # Descriptive Analysis

# %%
# Statistical Information
df.describe()
# Out:
#         CustomerID          Age         Income      AdSpend  ClickThroughRate  \
# count   8000.00000  8000.000000    8000.000000  8000.000000       8000.000000
# mean   11999.50000    43.625500   84664.196750  5000.944830          0.154829
# std     2309.54541    14.902785   37580.387945  2838.038153          0.084007
# min     8000.00000    18.000000   20014.000000   100.054813          0.010005
# 25%     9999.75000    31.000000   51744.500000  2523.221165          0.082635
# 50%    11999.50000    43.000000   84926.500000  5013.440044          0.154505
# 75%    13999.25000    56.000000  116815.750000  7407.989369          0.228207
# max    15999.00000    69.000000  149986.000000  9997.914781          0.299968
#
#        ConversionRate  WebsiteVisits  PagesPerVisit   TimeOnSite  \
# count     8000.000000    8000.000000    8000.000000  8000.000000
# mean         0.104389      24.751625       5.549299     7.727718
# std          0.054878      14.312269       2.607358     4.228218
# ...

# %% [markdown]
# # Data Cleaning

# %%
# check missing Values
df.isnull().sum()
# Out:
# CustomerID             0
# Age                    0
# Gender                 0
# Income                 0
# CampaignChannel        0
# CampaignType           0
# AdSpend                0
# ClickThroughRate       0
# ConversionRate         0
# WebsiteVisits          0
# PagesPerVisit          0
# TimeOnSite             0
# SocialShares           0
# EmailOpens             0
# EmailClicks            0
# PreviousPurchases      0
# LoyaltyPoints          0
# AdvertisingPlatform    0
# AdvertisingTool        0
# Conversion             0
# dtype: int64

# %%
# Types on Campaign Channels
df['CampaignChannel'].value_counts()
# Out:
# CampaignChannel
# Referral        1719
# PPC             1655
# Email           1557
# SEO             1550
# Social Media    1519
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Univariate Analysis

# %%
# Campaign Channel
df['CampaignChannel'].value_counts()
# Out:
# CampaignChannel
# Referral        1719
# PPC             1655
# Email           1557
# SEO             1550
# Social Media    1519
# Name: count, dtype: int64

# %%
#Campaign Type
df['CampaignType'].value_counts()
# Out:
# CampaignType
# Conversion       2077
# Awareness        1988
# Consideration    1988
# Retention        1947
# Name: count, dtype: int64

# %%
df['ConversionRate'].max()
# Out:
# np.float64(0.1999947079999166)

# %% [markdown]
# Age Distribution

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.title('Customer Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Income Distribution

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['Income'], bins=30, kde=True, color='salmon')
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Count')
plt.show()

# %%
# Gender Distribution
msc=df['Gender'].value_counts()
print(msc.index)
plt.pie(msc,labels=msc.index,autopct="%d%%")
plt.title('Marital Status')
plt.ylabel('')
plt.show()
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
# Campaign Channel Success

sns.countplot(x='CampaignChannel', data=df)
plt.title('Conversion Count by Campaign Channel')
plt.xticks(rotation=45)
plt.show()

# %%
# # Campaign Type Success

sns.countplot(x='CampaignType',hue='Gender', data=df)
plt.title('Conversion Count by Campaign Channel')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Click through rate and campaign type

# %%
sns.boxplot(x='CampaignType', y='ClickThroughRate', data=df)
plt.title('Click Through Rate by Campaign Type')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Awareness'),
#   Text(1, 0, 'Retention'),
#   Text(2, 0, 'Conversion'),
#   Text(3, 0, 'Consideration')])

# %%
# income vs AdSpend
sns.scatterplot(x='Income', y='AdSpend',hue='Conversion', data=df)
plt.title('Ad Spend vs Income (Colored by Conversion)')
# Out:
# Text(0.5, 1.0, 'Ad Spend vs Income (Colored by Conversion)')

# %% [markdown]
# Reviewing Email Clicks and Emails Opened

# %%
plt.figure(figsize=(4,3))
sns.histplot(df['EmailOpens'], kde=True, color='teal')
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.histplot(df['EmailClicks'], kde=True, color='purple')
plt.show()

# %% [markdown]
# # Insights
# 1. The marketing campaign seems to attract a middle-aged audience.
#
# 2. Female conversions are higher than males
#
# 3. Most customers fall within the 30-50 age range.
#
# 4. Referrals are best campaign channel
